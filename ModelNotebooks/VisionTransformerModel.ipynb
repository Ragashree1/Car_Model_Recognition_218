# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set seaborn style and configure plotting
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

img_path = "/kaggle/input/stanford-cars-dataset/cars_test/cars_test/00001.jpg"
image = Image.open(img_path)

plt.imshow(image)
plt.axis("off")
plt.title("Example Car Image")
plt.show()

# %%
# If you have a label file or directory structure
class_names = os.listdir("/kaggle/input/stanford-cars-dataset/cars_train/cars_train")
print("Number of classes:", len(class_names))
print("Class names:", class_names)
# Out:
# Number of classes: 8144
# ...

# %%
# If you have a label file or directory structure
class_names = os.listdir("/kaggle/input/stanford-cars-dataset/cars_test/cars_test")
print("Number of classes:", len(class_names))
print("Class names:", class_names)
# Out:
# Number of classes: 8041
# ...

# %%
from scipy.io import loadmat

# Correct paths based on Kaggle dataset structure
cars_meta = loadmat('/kaggle/input/cars-devkit/cars_meta.mat')

cars_train_annos = loadmat('/kaggle/input/cars-devkit/cars_train_annos.mat')
train_annos = cars_train_annos['annotations']  # Structured array

cars_test_annos = loadmat('/kaggle/input/cars-devkit/cars_test_annos.mat')
test_annos = cars_test_annos['annotations']

# %%
print(cars_meta)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013', '__version__': '1.0', '__globals__': [], 'class_names': array([[array(['AM General Hummer SUV 2000'], dtype='<U26'),
#         array(['Acura RL Sedan 2012'], dtype='<U19'),
#         array(['Acura TL Sedan 2012'], dtype='<U19'),
#         array(['Acura TL Type-S 2008'], dtype='<U20'),
#         array(['Acura TSX Sedan 2012'], dtype='<U20'),
#         array(['Acura Integra Type R 2001'], dtype='<U25'),
#         array(['Acura ZDX Hatchback 2012'], dtype='<U24'),
#         array(['Aston Martin V8 Vantage Convertible 2012'], dtype='<U40'),
#         array(['Aston Martin V8 Vantage Coupe 2012'], dtype='<U34'),
#         array(['Aston Martin Virage Convertible 2012'], dtype='<U36'),
#         array(['Aston Martin Virage Coupe 2012'], dtype='<U30'),
#         array(['Audi RS 4 Convertible 2008'], dtype='<U26'),
#         array(['Audi A5 Coupe 2012'], dtype='<U18'),
# ...

# %%
print(cars_train_annos)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013', '__version__': '1.0', '__globals__': [], 'annotations': array([[(array([[39]], dtype=uint8), array([[116]], dtype=uint8), array([[569]], dtype=uint16), array([[375]], dtype=uint16), array([[14]], dtype=uint8), array(['00001.jpg'], dtype='<U9')),
#         (array([[36]], dtype=uint8), array([[116]], dtype=uint8), array([[868]], dtype=uint16), array([[587]], dtype=uint16), array([[3]], dtype=uint8), array(['00002.jpg'], dtype='<U9')),
#         (array([[85]], dtype=uint8), array([[109]], dtype=uint8), array([[601]], dtype=uint16), array([[381]], dtype=uint16), array([[91]], dtype=uint8), array(['00003.jpg'], dtype='<U9')),
#         ...,
#         (array([[26]], dtype=uint8), array([[246]], dtype=uint8), array([[660]], dtype=uint16), array([[449]], dtype=uint16), array([[163]], dtype=uint8), array(['08142.jpg'], dtype='<U9')),
# ...

# %%
print(cars_test_annos)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Dec 14 14:13:07 2013', '__version__': '1.0', '__globals__': [], 'annotations': array([[(array([[30]], dtype=uint8), array([[52]], dtype=uint8), array([[246]], dtype=uint8), array([[147]], dtype=uint8), array(['00001.jpg'], dtype='<U9')),
#         (array([[100]], dtype=uint8), array([[19]], dtype=uint8), array([[576]], dtype=uint16), array([[203]], dtype=uint8), array(['00002.jpg'], dtype='<U9')),
#         (array([[51]], dtype=uint8), array([[105]], dtype=uint8), array([[968]], dtype=uint16), array([[659]], dtype=uint16), array(['00003.jpg'], dtype='<U9')),
#         ...,
#         (array([[33]], dtype=uint8), array([[27]], dtype=uint8), array([[602]], dtype=uint16), array([[252]], dtype=uint8), array(['08039.jpg'], dtype='<U9')),
#         (array([[33]], dtype=uint8), array([[142]], dtype=uint8), array([[521]], dtype=uint16), array([[376]], dtype=uint16), array(['08040.jpg'], dtype='<U9')),
# ...

# %%
# !pip install scipy pillow matplotlib

import os
import random
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# %%
train_annos_path = "/kaggle/input/cars-devkit/cars_train_annos.mat"

import scipy.io as sio

train_annos = sio.loadmat(train_annos_path)

# The "annotations" field is often a structured array of shape (1, N),
# so we select [0] to flatten it into a 1D list of annotations.
annotations = train_annos['annotations'][0]

print(f"Loaded {len(annotations)} annotations successfully.")
# Out:
# Loaded 8144 annotations successfully.

# %%
print("Number of training images:", len(annotations))
print("Fields in each annotation:", annotations[0].dtype.names)
print("Top 3 values in annotations:", annotations[:3])
# Out:
# Number of training images: 8144
# Fields in each annotation: ('bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class', 'fname')
# Top 3 values in annotations: [(array([[39]], dtype=uint8), array([[116]], dtype=uint8), array([[569]], dtype=uint16), array([[375]], dtype=uint16), array([[14]], dtype=uint8), array(['00001.jpg'], dtype='<U9'))
#  (array([[36]], dtype=uint8), array([[116]], dtype=uint8), array([[868]], dtype=uint16), array([[587]], dtype=uint16), array([[3]], dtype=uint8), array(['00002.jpg'], dtype='<U9'))
#  (array([[85]], dtype=uint8), array([[109]], dtype=uint8), array([[601]], dtype=uint16), array([[381]], dtype=uint16), array([[91]], dtype=uint8), array(['00003.jpg'], dtype='<U9'))]

# %%
print(annotations.shape)
print(annotations.dtype)
print(annotations.dtype.names)
# Out:
# (8144,)
# [('bbox_x1', 'O'), ('bbox_y1', 'O'), ('bbox_x2', 'O'), ('bbox_y2', 'O'), ('class', 'O'), ('fname', 'O')]
# ('bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class', 'fname')

# %% [markdown]
# Accessing mat annotation within the array

# %%
for i in range(3):  # Loop through the first 3 annotations
    ann = annotations[i]  

    filename = ann['fname'][0]  # Extract filename
    class_idx = ann['class'][0][0]  # Extract class index (removes extra brackets)

    # Extract bbox values correctly by converting from arrays to scalars
    x1 = ann['bbox_x1'][0][0]  
    y1 = ann['bbox_y1'][0][0]
    x2 = ann['bbox_x2'][0][0]
    y2 = ann['bbox_y2'][0][0]

    print(f"Annotation {i}:")
    print(f"  Filename  : {filename}")
    print(f"  Class idx : [{class_idx}]")
    print(f"  BBox      : (x1=[[{x1}]], y1=[[{y1}]], x2=[[{x2}]], y2=[[{y2}]])")
    print("-----------")
# Out:
# Annotation 0:
#   Filename  : 00001.jpg
#   Class idx : [14]
#   BBox      : (x1=[[39]], y1=[[116]], x2=[[569]], y2=[[375]])
# -----------
# Annotation 1:
#   Filename  : 00002.jpg
#   Class idx : [3]
#   BBox      : (x1=[[36]], y1=[[116]], x2=[[868]], y2=[[587]])
# -----------
# Annotation 2:
#   Filename  : 00003.jpg
#   Class idx : [91]
#   BBox      : (x1=[[85]], y1=[[109]], x2=[[601]], y2=[[381]])
# -----------

# %%
import numpy as np

# Convert class_names to a NumPy array to ensure correct indexing
class_names = np.array(class_names)

for i in range(3):  
    ann = annotations[i]  

    # Extract values correctly
    x1 = ann['bbox_x1'].item()
    y1 = ann['bbox_y1'].item()
    x2 = ann['bbox_x2'].item()
    y2 = ann['bbox_y2'].item()
    class_idx = ann['class'].item()  
    fname = ann['fname'][0]  

    # Get the correct class name
    car_name = class_names[class_idx - 1][0]  # Adjusted for correct indexing

    print(f"Annotation {i+1}:")
    print(f"  Filename : {fname}")
    print(f"  Class idx: {class_idx} -> {car_name}")
    print(f"  BBox     : (x1={x1}, y1={y1}, x2={x2}, y2={y2})")
    print("-----------")
# Out:
# Annotation 1:
#   Filename : 00001.jpg
#   Class idx: 14 -> 0
#   BBox     : (x1=39, y1=116, x2=569, y2=375)
# -----------
# Annotation 2:
#   Filename : 00002.jpg
#   Class idx: 3 -> 0
#   BBox     : (x1=36, y1=116, x2=868, y2=587)
# -----------
# Annotation 3:
#   Filename : 00003.jpg
#   Class idx: 91 -> 0
#   BBox     : (x1=85, y1=109, x2=601, y2=381)
# -----------

# %%
# !pip install torch torchvision

# %%
import torch
import torchvision
import torchvision.transforms as T
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torchvision.models as models

# %%
transform = T.Compose([
    T.Resize((224, 224)),  # Typical input size for ResNet
    T.ToTensor(),
    T.Normalize(
        mean=[0.485, 0.456, 0.406],  # ImageNet means
        std=[0.229, 0.224, 0.225]    # ImageNet stds
    )
])

# %%
annotations_list = []

for anno in annotations:
    bbox_x1 = int(anno['bbox_x1'][0][0])
    bbox_x2 = int(anno['bbox_x2'][0][0])
    bbox_y1 = int(anno['bbox_y1'][0][0])
    bbox_y2 = int(anno['bbox_y2'][0][0])
    class_id = int(anno['class'][0][0])
    fname = str(anno['fname'][0])

    annotations_list.append({
        'bbox_x1': bbox_x1,
        'bbox_y1': bbox_y1,
        'bbox_x2': bbox_x2,
        'bbox_y2': bbox_y2,
        'class_id': class_id,
        'fname': fname
    })

# Print the first 2 dicts for sanity check
for i in range(2):
    print(annotations_list[i])
# Out:
# {'bbox_x1': 39, 'bbox_y1': 116, 'bbox_x2': 569, 'bbox_y2': 375, 'class_id': 14, 'fname': '00001.jpg'}
# {'bbox_x1': 36, 'bbox_y1': 116, 'bbox_x2': 868, 'bbox_y2': 587, 'class_id': 3, 'fname': '00002.jpg'}

# %% [markdown]
# Display specific Car based on id

# %%
import cv2
import matplotlib.pyplot as plt
import os

images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train/"

# Choose a specific annotation index to display
idx = 0  # Change this to select a different car image

anno = annotations_list[idx]

# Print available keys to debug
print("Available keys in annotation:", anno.keys())

# Extract filename properly
fname = anno['fname'][0] if isinstance(anno['fname'], (list, tuple)) else anno['fname']

#  Ensure filename matches dataset format (5-digit numbers with ".jpg")
if not fname.endswith(".jpg"):
    fname = f"{int(fname):05d}.jpg"  # Convert to 5-digit format

# Construct the correct file path
img_path = os.path.join(images_folder, fname)

# Verify if the file exists before reading
if not os.path.exists(img_path):
    print(f"❌ Image file not found: {img_path}")
    print("Available files:", os.listdir(images_folder)[:10])  # Print first 10 files for debugging
else:
    # Read the image
    img = cv2.imread(img_path)
    if img is None:
        print(f"❌ Could not read image: {img_path}")
    else:
        # Fix KeyError: Use the correct key name
        class_id = int(anno['class_id'])

        # Ensure class names are extracted correctly
        if isinstance(class_names, dict):  # If loaded from .mat
            class_names = class_names['class_names'][0]  # Extract correctly

        # Fix class name retrieval
        if isinstance(class_names[class_id - 1], list):
            car_name = class_names[class_id - 1][0]  # Extract first element if nested
        else:
            car_name = class_names[class_id - 1]  # Directly use it if it's a string

        # Extract bbox coordinates
        x1, y1, x2, y2 = int(anno['bbox_x1']), int(anno['bbox_y1']), int(anno['bbox_x2']), int(anno['bbox_y2'])

        # Draw the bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Convert to RGB for matplotlib
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(6, 4))
        plt.imshow(img_rgb)
        plt.title(f"{fname} (class_id={class_id}) {car_name}")  
        plt.axis('off')
        plt.show()
# Out:
# Available keys in annotation: dict_keys(['bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class_id', 'fname'])

# %%
import cv2
import scipy.io
import matplotlib.pyplot as plt

# Load Metadata and Class Names
meta_path = "/kaggle/input/cars-devkit/cars_meta.mat"
cars_meta = scipy.io.loadmat(meta_path)

# Extract class names properly
class_names = [name[0] for name in cars_meta['class_names'][0]]

# Load Annotations
annos_path = "/kaggle/input/cars-devkit/cars_train_annos.mat"
cars_train_annos = scipy.io.loadmat(annos_path)

# Extract 'annotations' array
annotations_list = cars_train_annos['annotations'][0]

# Define Image Folder Path for Kaggle
images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train/"

# Choose a specific annotation index
idx = 0  

# Extract annotation details
anno = annotations_list[idx]

# Check available keys in annotation
print("Available keys in annotation:", anno.dtype.names)

fname = anno['fname'][0]  # File name
x1, y1, x2, y2 = int(anno['bbox_x1'][0][0]), int(anno['bbox_y1'][0][0]), int(anno['bbox_x2'][0][0]), int(anno['bbox_y2'][0][0])

# Corrected: Use 'class' instead of 'class_id'
class_id = int(anno['class'][0][0])  

# Get correct car name
car_name = class_names[class_id - 1]  # Adjust for 1-based indexing

# Construct full image path
img_path = images_folder + fname

# Read and display image
img = cv2.imread(img_path)

if img is None:
    print(f"❌ Could not read image: {img_path}")
else:
    # Draw bounding box
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Convert BGR to RGB (for matplotlib)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Plot image with bounding box and class name
    plt.figure(figsize=(6, 4))
    plt.imshow(img_rgb)
    plt.title(f"{fname} (class_id={class_id}) {car_name}")
    plt.axis('off')
    plt.show()
# Out:
# Available keys in annotation: ('bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2', 'class', 'fname')

# %%
import cv2
import matplotlib.pyplot as plt
import os
import scipy.io

# Load metadata file (contains class names)
meta_path = "/kaggle/input/cars-devkit/cars_meta.mat"
cars_meta = scipy.io.loadmat(meta_path)

# Extract class names properly
class_names = [name[0] for name in cars_meta['class_names'][0]]

# Load annotations (assuming it is already loaded as annotations_list)
annotations_list = scipy.io.loadmat("/kaggle/input/cars-devkit/cars_train_annos.mat")["annotations"][0]

# Define the correct path for Kaggle dataset images
images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train"

# Display multiple images with bounding boxes and correct class names
for i in range(3):  # Update this number to display more images if needed
    anno = annotations_list[i]  # Get annotation for the image

    # Extract filename (Ensure proper string extraction)
    fname = str(anno["fname"][0])  
    img_path = os.path.join(images_folder, fname)  # Full path to the image

    # Read the image
    img = cv2.imread(img_path)
    if img is None:
        print(f"Could not read image: {img_path}")
        continue

    # Extract bounding box
    x1, y1, x2, y2 = (
        int(anno["bbox_x1"][0][0]),
        int(anno["bbox_y1"][0][0]),
        int(anno["bbox_x2"][0][0]),
        int(anno["bbox_y2"][0][0]),
    )

    # Get class ID and map it to the correct car name
    class_id = int(anno["class"][0][0])  # Ensure proper extraction
    car_name = class_names[class_id - 1]  # Adjust 1-based index to 0-based

    # Draw bounding box
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Plot the image
    plt.figure(figsize=(6, 4))
    plt.imshow(img_rgb)
    plt.title(f"{fname} (class_id={class_id}) {car_name}")
    plt.axis("off")
    plt.show()

# %% [markdown]
# Load the Pretrained Model

# %%
# Load the Vision Transformer (ViT) model without downloading weights
model = models.vit_b_16(weights=None)  # We are going to load weights manually

# Load manually uploaded weights
weights_path = "/kaggle/input/vit-b-16/vit_b_16-c867db91.pth"  # Correct path for the manually uploaded weights
model.load_state_dict(torch.load(weights_path))

# Modify classifier for 196 classes (Stanford Cars dataset)
model.heads.head = torch.nn.Linear(model.heads.head.in_features, 196)  # 196 classes for Stanford Cars

# Set model to evaluation mode
model.eval()
# Out:
# <ipython-input-23-de217694824f>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights_path))
# VisionTransformer(
# ...

# %%
import os
import torch
import numpy as np
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as T
from PIL import Image
import scipy.io
import matplotlib.pyplot as plt
import cv2
from torchvision import models

# Path to your dataset
images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train/"

# Load annotations
annotations_path = "/kaggle/input/cars-devkit/cars_train_annos.mat"
cars_train_annos = scipy.io.loadmat(annotations_path)

# Extract 'annotations' array
annotations_list = cars_train_annos['annotations'][0]

# Load metadata file (contains class names)
meta_path = "/kaggle/input/cars-devkit/cars_meta.mat"
cars_meta = scipy.io.loadmat(meta_path)

# Extract class names properly
class_names = [name[0] for name in cars_meta['class_names'][0]]

# Define the transformation for image preprocessing
transform = T.Compose([
    T.Resize((224, 224)),  # Resize to the input size for ViT
    T.ToTensor(),
    T.Normalize(
        mean=[0.485, 0.456, 0.406],  # ImageNet mean values
        std=[0.229, 0.224, 0.225]    # ImageNet std values
    )
])

# Dataset class to load images and annotations
class CarsDataset(Dataset):
    def __init__(self, annotations, transform=None):
        self.annotations = annotations
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, idx):
        anno = self.annotations[idx]
        
        # Correcting the way we handle the file name (anno['fname'] is an ndarray)
        fname = anno['fname'][0]  # Extract the filename properly as a string
        img_path = os.path.join(images_folder, fname)  # Join it with the image folder path
        image = Image.open(img_path)

        # Ensure the image is in RGB format
        if image.mode != 'RGB':
            image = image.convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Adjusted to 'class' instead of 'class_id'
        label = anno['class'][0][0]  # Using 'class' to get the label
        return image, label

# Prepare DataLoader for the dataset
dataset = CarsDataset(annotations_list, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
# Load the Vision Transformer (ViT) model without downloading weights
model = models.vit_b_16(weights=None)  # Vision Transformer model with ViT-B-16 configuration

# Load manually uploaded weights for ViT model
weights_path = "/kaggle/input/vit-b-16/vit_b_16-c867db91.pth"  # Correct path for the manually uploaded weights
model.load_state_dict(torch.load(weights_path))

# Modify classifier for 196 classes (Stanford Cars dataset)
model.heads.head = torch.nn.Linear(model.heads.head.in_features, 196)  # 196 classes for Stanford Cars

# Set model to evaluation mode
model.eval()

# Set device for model (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Evaluate the model on the dataset
correct = 0
total = 0
with torch.no_grad():
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total}%')
# Out:
# <ipython-input-25-037aa8ae6995>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights_path))
# Accuracy: 0.6139489194499018%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

correct = 0
total = 0
all_labels = []
all_preds = []

with torch.no_grad():
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Store labels and predictions for later calculation of precision, recall, and f1-score
        all_labels.extend(labels.cpu().numpy())  # Move to CPU and convert to numpy
        all_preds.extend(predicted.cpu().numpy())  # Move to CPU and convert to numpy

# Calculate the accuracy
accuracy = 100 * correct / total
print(f'Accuracy: {accuracy}%')

# Calculate precision, recall, and f1-score
precision = precision_score(all_labels, all_preds, average='weighted')  # Weighted average to handle class imbalance
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')

# Print precision, recall, and F1 score
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.6139489194499018%
# Precision: 0.0090
# Recall: 0.0061
# F1 Score: 0.0030
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Pretrained

# %%
import os
import torch
import numpy as np
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as T
from PIL import Image
import scipy.io
import matplotlib.pyplot as plt
from torchvision import models
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import precision_score, recall_score, f1_score

# Path to your dataset
images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train/"

# Load annotations
annotations_path = "/kaggle/input/cars-devkit/cars_train_annos.mat"
cars_train_annos = scipy.io.loadmat(annotations_path)

# Extract 'annotations' array
annotations_list = cars_train_annos['annotations'][0]

# Load metadata file (contains class names)
meta_path = "/kaggle/input/cars-devkit/cars_meta.mat"
cars_meta = scipy.io.loadmat(meta_path)

# Extract class names properly
class_names = [name[0] for name in cars_meta['class_names'][0]]

# Define the transformation for image preprocessing
transform = T.Compose([
    T.RandomHorizontalFlip(),
    T.RandomRotation(10),
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Dataset class to load images and annotations
class CarsDataset(Dataset):
    def __init__(self, annotations, transform=None):
        self.annotations = annotations
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, idx):
        anno = self.annotations[idx]
        fname = anno['fname'][0]  # Extract the filename properly as a string
        img_path = os.path.join(images_folder, fname)
        image = Image.open(img_path)

        if image.mode != 'RGB':
            image = image.convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = anno['class'][0][0] - 1  # Adjusted label for correct indexing
        return image, label

# Prepare DataLoader for the dataset
dataset = CarsDataset(annotations_list, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Load pretrained ViT model
model = models.vit_b_16(pretrained=True)

# Modify classifier for 196 classes (Stanford Cars dataset)
model.heads.head = torch.nn.Linear(model.heads.head.in_features, 196)

# Freeze all layers except the classifier
for param in model.parameters():
    param.requires_grad = False
for param in model.heads.head.parameters():
    param.requires_grad = True

# Set model to evaluation mode
model.eval()

# Set device for model (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Training loop
num_epochs = 30
for epoch in range(num_epochs):
    running_loss = 0.0
    model.train()
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    scheduler.step()

    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(dataloader)}')

# Evaluate the model
all_labels = []
all_preds = []
correct = 0
total = 0

model.eval()  # Set model to evaluation mode
with torch.no_grad():
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

        # Calculate accuracy
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Calculate accuracy
accuracy = 100 * correct / total
print(f'Accuracy: {accuracy:.4f}%')

# Calculate precision, recall, and F1 score
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 232MB/s]
# Epoch 1/30, Loss: 4.919619219910865
# Epoch 2/30, Loss: 4.297917743757659
# Epoch 3/30, Loss: 3.9145427956300622
# Epoch 4/30, Loss: 3.6355705242530973
# ...

# %%
import os
import torch
import numpy as np
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as T
from PIL import Image
import scipy.io
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchvision import models

# Path to your dataset
images_folder = "/kaggle/input/stanford-cars-dataset/cars_train/cars_train/"

# Load annotations
annotations_path = "/kaggle/input/cars-devkit/cars_train_annos.mat"
cars_train_annos = scipy.io.loadmat(annotations_path)

# Extract 'annotations' array
annotations_list = cars_train_annos['annotations'][0]

# Load metadata file (contains class names)
meta_path = "/kaggle/input/cars-devkit/cars_meta.mat"
cars_meta = scipy.io.loadmat(meta_path)

# Extract class names properly
class_names = [name[0] for name in cars_meta['class_names'][0]]

# Define the transformation for image preprocessing (with data augmentation)
transform = T.Compose([
    T.RandomHorizontalFlip(),
    T.RandomRotation(10),
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Dataset class to load images and annotations
class CarsDataset(Dataset):
    def __init__(self, annotations, transform=None):
        self.annotations = annotations
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, idx):
        anno = self.annotations[idx]
        fname = anno['fname'][0]  # Extract the filename properly as a string
        img_path = os.path.join(images_folder, fname)
        image = Image.open(img_path)

        if image.mode != 'RGB':
            image = image.convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = anno['class'][0][0] - 1  # Adjusted label for correct indexing
        return image, label

# Prepare DataLoader for the dataset
dataset = CarsDataset(annotations_list, transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Load pretrained ViT model
model = models.vit_b_16(pretrained=True)

# Modify classifier for 196 classes (Stanford Cars dataset)
model.heads.head = torch.nn.Linear(model.heads.head.in_features, 196)

# Freeze all layers except the classifier
for param in model.parameters():
    param.requires_grad = False
for param in model.heads.head.parameters():
    param.requires_grad = True

# Set device for model (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Track training loss and accuracy
train_losses = []
train_accuracies = []

# Training loop
num_epochs = 30
for epoch in range(num_epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    model.train()
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        # Accuracy calculation for training set
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    scheduler.step()

    train_losses.append(running_loss / len(dataloader))
    train_accuracies.append(100 * correct / total)

    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(dataloader)}, Accuracy: {100 * correct / total}%')

# Plot Training Loss and Accuracy
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss vs Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy', color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy vs Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluate the model
all_labels = []
all_preds = []
all_probs = []

model.eval()  # Set model to evaluation mode
with torch.no_grad():
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        
        # Save labels and predictions
        _, predicted = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

        # Save output probabilities for ROC curve
        probs = torch.nn.functional.softmax(outputs, dim=1)
        all_probs.extend(probs.cpu().numpy())

# Calculate precision, recall, and F1 score
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')

# ROC Curve
# Binarize the labels for ROC calculation (needed for multi-class classification)
all_labels_bin = label_binarize(all_labels, classes=np.arange(196))

# Calculate the ROC curve for each class
fpr, tpr, _ = roc_curve(all_labels_bin.ravel(), np.array(all_probs).ravel())
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/30, Loss: 4.92938471401439, Accuracy: 4.481827111984283%
# Epoch 2/30, Loss: 4.309052569258447, Accuracy: 14.845284872298624%
# Epoch 3/30, Loss: 3.9216909100027646, Accuracy: 22.826620825147348%
# Epoch 4/30, Loss: 3.639561366099937, Accuracy: 30.279960707269154%
# Epoch 5/30, Loss: 3.417583152359607, Accuracy: 35.142436149312374%
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# After model evaluation (assuming all_labels, all_preds, and all_probs are already defined)
# Identify misclassified samples
misclassified_indices = np.where(np.array(all_labels) != np.array(all_preds))[0]

# Collect misclassified information
misclassified_labels = np.array(all_labels)[misclassified_indices]
misclassified_preds = np.array(all_preds)[misclassified_indices]

# Optionally, you can also look at misclassified probabilities if needed
misclassified_probs = np.array(all_probs)[misclassified_indices]

# Print out some information about the misclassifications
print(f"Number of misclassified samples: {len(misclassified_indices)}")
print(f"Misclassified labels vs Predictions: \n{list(zip(misclassified_labels, misclassified_preds))[:10]}")  # Show first 10

# If you'd like to visualize some misclassified samples:
plt.figure(figsize=(12, 10))

# Display first 5 misclassified samples (adjust the number as needed)
for i, idx in enumerate(misclassified_indices[:5]):
    img_path = os.path.join(images_folder, dataset.annotations[idx]['fname'][0])  # Use the correct file path
    image = Image.open(img_path)
    
    plt.subplot(1, 5, i+1)
    plt.imshow(image)
    plt.title(f"True: {misclassified_labels[i]}, Pred: {misclassified_preds[i]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Number of misclassified samples: 2857
# Misclassified labels vs Predictions:
# [(117, 175), (135, 48), (106, 45), (183, 81), (27, 161), (66, 182), (131, 129), (37, 92), (188, 75), (163, 164)]
